# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('covid19_sample_data.csv')

# %%
df.head()
# Out:
#          date    country  total_cases  new_cases  total_deaths  new_deaths  \
# 0  2020-01-22  Country_0        16795        288          2514          40
# 1  2020-01-23  Country_1         1860        436          3526          53
# 2  2020-01-24  Country_2        77820        661          4681          45
# 3  2020-01-25  Country_3        55886        276          1247          59
# 4  2020-01-26  Country_4         7265        709          3902          59
#
#    total_recoveries  active_cases
# 0             32441        -18160
# 1             39129        -40795
# 2             62368         10771
# 3             44760          9879
# 4             23478        -20115

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1000 non-null   object
#  1   country           1000 non-null   object
#  2   total_cases       1000 non-null   int64
#  3   new_cases         1000 non-null   int64
#  4   total_deaths      1000 non-null   int64
#  5   new_deaths        1000 non-null   int64
#  6   total_recoveries  1000 non-null   int64
#  7   active_cases      1000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 62.6+ KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         total_cases    new_cases  total_deaths   new_deaths  total_recoveries  \
# count   1000.000000  1000.000000   1000.000000  1000.000000       1000.000000
# mean   49990.156000   499.129000   2446.931000    48.774000      44456.442000
# std    28872.074468   296.346878   1434.924358    28.027245      26161.597729
# min     1055.000000     0.000000      1.000000     0.000000        112.000000
# 25%    24467.000000   242.000000   1160.750000    25.000000      22008.750000
# 50%    50866.500000   499.500000   2456.000000    48.000000      43938.000000
# 75%    74658.500000   760.250000   3694.500000    72.000000      66684.000000
# max    99806.000000   997.000000   4986.000000    99.000000      89963.000000
#
#        active_cases
# count   1000.000000
# mean    3086.783000
# std    40611.375067
# min   -91423.000000
# 25%   -27340.750000
# 50%     3002.500000
# 75%    32890.250000
# max    91741.000000

# %%
print(df.dtypes)  

df_numeric = df.select_dtypes(include=['number'])

plt.figure(figsize=(10, 8))
sns.heatmap(df_numeric.corr(), annot=True)
plt.show()
# Out:
# date                object
# country             object
# total_cases          int64
# new_cases            int64
# total_deaths         int64
# new_deaths           int64
# total_recoveries     int64
# active_cases         int64
# dtype: object

# %%
features = ['total_cases', 'new_cases', 'total_deaths', 'new_deaths']
target = ['total_recoveries', 'active_cases']
x = df[features]
y = df[target]
x.shape, y.shape
# Out:
# ((1000, 4), (1000, 2))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=70)
y_test.shape
# Out:
# (250, 2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(x_test)

# %%
score = lr.score(x_test,y_test)
print('akurasi model regresi linear = ', score)
# Out:
# akurasi model regresi linear =  0.30201371843972785

# %%
input_data = np.array([[21.5,86.0,83.1,28.4]])

prediction = lr.predict(input_data)
print('total kesembuhan :', prediction)
# Out:
# estimasi panjang dan berat ikan : [[ 46272.12195609 -46333.72195609]]
# c:\Users\Eratech\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
